# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
df = pd.read_csv('./csv/dataset_train.csv')

# %%
df.head()
# Out:
#   id_produto             nome_produto data_última_venda  \
# 0       P001            Shampoo Minus        2025-05-20
# 1       P002              Perfume Qui        2025-05-18
# 2       P003       Óleo corporal Quia        2025-05-09
# 3       P004   Óleo corporal Deleniti        2025-04-07
# 4       P005  Creme Hidratante Fugiat        2025-07-11
#
#    quantidade_em_estoque  vendas_no_período  estoque_no_início_do_período  \
# 0                     97                 88                           185
# 1                     30                 47                            77
# 2                     54                129                           183
# 3                     46                 77                           123
# 4                     27                  8                            35
#
#    estoque_no_fim_do_período  estoque_médio rotatividade
# 0                         97          141.0         alta
# 1                         30           53.5         alta
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_produto                    1000 non-null   object
#  1   nome_produto                  1000 non-null   object
#  2   data_última_venda             1000 non-null   object
#  3   quantidade_em_estoque         1000 non-null   int64
#  4   vendas_no_período             1000 non-null   int64
#  5   estoque_no_início_do_período  1000 non-null   int64
#  6   estoque_no_fim_do_período     1000 non-null   int64
#  7   estoque_médio                 1000 non-null   float64
#  8   rotatividade                  1000 non-null   object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 70.4+ KB

# %%
df["rotatividade"].value_counts()
# Out:
# rotatividade
# alta     596
# baixa    404
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sbn.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.show()
